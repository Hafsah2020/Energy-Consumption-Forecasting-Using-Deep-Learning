# %%
import pandas as pd
import numpy as np

# %%
data_19 = pd.read_excel('../data/raw_data/2019 Power sector Energy Generated.xlsx', sheet_name = 'Energy Consumed (MWH) 2019', header = 1, index_col = 0)
data_19 = data_19.drop([np.nan, 'JAN-JUNE TOTAL', 'JUL-DEC TOTAL'])

# %%
data_19
# Out:
#                    ABUJA      IBADAN         EKO       IKEJA       BENIN  \
# REGION
# JANUARY        320061.47   300517.35   296600.74   312172.06   223259.42
# FEBRUARY       299146.05   282012.62   289100.56   309221.44   216306.22
# MARCH          357128.35   285941.91   327956.86   360745.64   228707.71
# APRIL          341874.02   283503.08   274755.11   322408.60   229247.05
# MAY            300917.63   293824.75   291532.68   337215.92   188596.97
# JUNE           318251.01   268959.20   263948.15   328926.25   165231.22
# JULY           298248.45   296929.18   289065.84   338912.36   188120.80
# AUGUST         322835.63   305772.70   310502.47   350778.87   182425.49
# SEPTEMBER      267685.55   268909.60   275655.05   337057.65   182952.06
# OCTOBER        278072.54   287914.26   269595.35   334432.30   177257.33
# NOVEMBER       305207.00   312465.05   306970.12   364651.69   189377.27
# DECEMBER       290075.52   336656.92   315507.01   391448.40   199816.32
# ...

# %%
with pd.ExcelWriter('../data/processed_data/Energy_consumption.xlsx') as writer:
    data_19.to_excel(writer, sheet_name = 'Consumption in 2019')

# %%
data_20 = pd.read_excel('../data/raw_data/Energy report 2020.xlsx', sheet_name = 'Monthly',skiprows = 37, index_col = 0)

# %%
data_20.columns = ['Source', 'Jan-20', 'Feb-20', 'Mar-20', 'Q1 2020', 'Apr-20', 'May-20', 'Jun-20', 'Q2 2020', 'Jul-20', 'Aug-20', 'Sep-20', 'Q3 2020', 'Oct-20', 'Nov-20', 'Dec-20', 'Q4 2020']

# %%
data_20
# Out:
#                   Source      Jan-20      Feb-20      Mar-20      Q1 2020  \
# AFAM (I-V)       Thermal   54.000000   57.000000   53.000000   164.000000
# GEREGU           Thermal  200.588000  158.909000   98.808000   458.305000
# EGBIN            Thermal  377.119100  400.626100  425.107700  1202.852900
# SAPELE           Thermal   19.857120   17.424090   15.698340    52.979550
# UGHELLI          Thermal  187.322500  162.807800  200.673200   550.803500
# SHIRORO            Hydro  203.200000  209.450000  260.740000   673.390000
# KAINJI             Hydro  299.672000  289.799700  294.255000   883.726700
# JEBBA              Hydro  274.839100  215.117200  220.672500   710.628800
# AES BARGE        Thermal         NaN         NaN         NaN     0.000000
# OKPAI            Thermal   94.497100   68.372100   96.881400   259.750600
# AFAM VI          Thermal  120.690856  131.787051  221.000000   473.477907
# OMOKU            Thermal   51.079700   48.950500   47.308800   147.339000
# ...

# %%
with pd.ExcelWriter('../data/processed_data/Energy_consumption.xlsx', engine = 'openpyxl', mode = "a") as writer:
    data_20.to_excel(writer, sheet_name = 'Consumption in 2020')

# %%
data_21 = pd.read_excel('../data/raw_data/DISCOS ELECTRICITY REPORT 2021.xlsx' ,skiprows = 2, nrows = 13, header = 0, index_col = 1)

# %%
data_21 = data_21.drop(['Unnamed: 0'], axis =1)

# %%
data_21.columns = ['JANUARY', 'FEBRUARY', 'MARCH', 'APRIL', 'MAY', 'JUNE', 'JULY',
       'AUGUST', 'SEPTEMBER', 'OCTOBER', 'NOVEMBER', 'DECEMBER', 'Total', '2020', 'a', 'b', 'c']

# %%
data_21 = data_21.drop([ 'a', 'b', 'c'], axis =1)

# %%
data_21
# Out:
#                           JANUARY     FEBRUARY        MARCH        APRIL  \
# DISCOS
# TOTAL                 2097.568375  2101.253905  1973.366755  2042.986540
# ABUJA (AEDC)           218.000000   226.000000   229.000000   245.000000
# BENIN (BEDC)           200.504476   203.848963   179.630103   202.004241
# EKO (EKEDC)            300.000000   297.880287   271.590137   262.000000
# ENUGU (EEDC)           193.000000   201.000000   184.000000   179.000000
# IBADAN (IBEDC)         300.645202   305.318615   268.273762   270.246883
# IKEJA (IEDC)           359.398436   359.917321   351.405779   352.701161
# JOS (JEDC)              69.560678    69.514924    68.391723    67.497874
# KADUNA (KDEDC)         144.000000   138.000000   129.000000   150.000000
# KANO (KEDC)            123.187681   119.820479   121.516274   132.157170
# PORT HARCOURT (PEDC)   142.271902   135.953317   138.558976   146.379211
# YOLA (YEDC)             47.000000    44.000000    32.000000    36.000000
# ...

# %%
with pd.ExcelWriter('../data/processed_data/Energy_consumption.xlsx', engine = 'openpyxl', mode = "a") as writer:
    data_21.to_excel(writer, sheet_name = 'Consumption in 2021')

# %%
data_22_1 = pd.read_excel('../data/raw_data/ELECTRICIY DATA 2015-Q4 2022.xlsx' ,skiprows = 65, header = 0, index_col = 0)

# %%
data_22_1
# Out:
#                       2015-01-01 00:00:00  2015-02-01 00:00:00  \
# DISCOS                        1731.976127          1699.355150
# ABUJA (AEDC)                   246.000000           250.000000
# BENIN (BEDC)                   165.020000           130.930000
# EKO (EKEDC)                    191.795167           195.000000
# ENUGU (EEDC)                   162.000000           159.000000
# IBADAN (IBEDC)                 235.229052           236.538056
# IKEJA (IEDC)                   250.701908           253.557094
# JOS (JEDC)                      91.000000           120.000000
# KADUNA (KDEDC)                 130.230000           127.430000
# KANO (KEDC)                     87.000000            72.870000
# PORT HARCOURT (PEDC)           152.000000           134.630000
# YOLA (YEDC)                     21.000000            19.400000
#
#                       2015-03-01 00:00:00  2015-04-01 00:00:00  \
# DISCOS                        1522.954093          1587.924630
# ...

# %%
data_22_2 = pd.read_excel('../data/raw_data/ELECTRICIY DATA 2015-Q2 2022.xlsx' ,skiprows = 65, header = 0, index_col = 0)[['Q1', 'Q2']]

# %%
data_22_2
# Out:
#                                Q1           Q2
# DISCOS                5955.515410  5226.973067
# ABUJA (AEDC)           649.000000   616.000000
# BENIN (BEDC)           603.004095   546.155633
# EKO (EKEDC)            754.387434   627.000000
# ENUGU (EEDC)           530.000000   464.000000
# IBADAN (IBEDC)         724.187538   621.405170
# IKEJA (IEDC)           987.211879   835.721501
# JOS (JEDC)             296.361134   267.485257
# KADUNA (KDEDC)         473.000000   434.000000
# KANO (KEDC)            413.200000   310.000000
# PORT HARCOURT (PEDC)   395.569923   377.004425
# YOLA (YEDC)            129.593405   128.201081
